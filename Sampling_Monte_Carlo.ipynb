# %% [markdown]
# # Sampling using Monte Carlo
#
# Change the parameters below to generate new results

# %%
# Using numpy to support math operations with random numbers

import numpy as np

# csv module to export results

import csv

# %%
# CHANGE PARAMETERS HERE!

# min sample_size, max_sample_size => Maximum Sample Size to be simulated
min_sample_size = 100
max_sample_size = 1000

# p => Event Probability
p = 0.005

# e => Error rate
e = 0.01

# s => Number of simulations. Anything more than 10000 simulations won't
#      change responses quite much
s = 10000

# %%
# Functions to generate sample simulations

def sim_generator(sample_size):
  results = np.zeros(s) # generate an empty array to be populated with results
  
  for it in np.arange(0,s):  # Iterate over number of simulations
    arr = np.random.binomial(1,p,sample_size) # Simulate event on sample size
    num = np.count_nonzero(arr) # count the number of successes
    num_adjusted = np.random.binomial(1,1-e,num) # adjust for the error rate
    num_count = np.count_nonzero(num_adjusted) # count adjusted events
    response = float(num_count >= 1) # convert responses to final array
    results[it] = response # populate responses in final array
  
  return np.count_nonzero(results) / s 
  # Return % of simulations in which we have at least one success, 
  # given the sample_size
  

def sim_multiple_samples(min_size,max_size):
  """
  This function simulates multiple samples, generating a dictionary.
  In the left hand
  """
  sim_results = {}
  
  for i in np.arange(min_size,max_size+1):
    sim_results[str(i)] = sim_generator(i)
    
  return sim_results

# %%
# Running the model

sample_prob = sim_multiple_samples(min_sample_size,max_sample_size)

# %%
# Generating CSV to export

with open('final_results.csv', 'w') as f:
    f.write('sample_size,prob_at_least_one_pct\n')
    for key in sample_prob.keys():
        f.write("%s,%s\n"%(key,sample_prob[key]))

# %%
# Checking results:
print("Number of simulations:",s,"\n")

for key in sample_prob.keys():
  print("Sample size:",key," --> Probability of having at least 01 success:",sample_prob[key])
# Out:
# Number of simulations: 10000
#
# Sample size: 100  --> Probability of having at least 01 success: 0.3899
# Sample size: 101  --> Probability of having at least 01 success: 0.3841
# Sample size: 102  --> Probability of having at least 01 success: 0.3998
# Sample size: 103  --> Probability of having at least 01 success: 0.3977
# Sample size: 104  --> Probability of having at least 01 success: 0.4054
# Sample size: 105  --> Probability of having at least 01 success: 0.4
# Sample size: 106  --> Probability of having at least 01 success: 0.416
# Sample size: 107  --> Probability of having at least 01 success: 0.4154
# Sample size: 108  --> Probability of having at least 01 success: 0.4149
# Sample size: 109  --> Probability of having at least 01 success: 0.4187
# Sample size: 110  --> Probability of having at least 01 success: 0.4198
# Sample size: 111  --> Probability of having at least 01 success: 0.424
# Sample size: 112  --> Probability of having at least 01 success: 0.4243
# Sample size: 113  --> Probability of having at least 01 success: 0.4272
# Sample size: 114  --> Probability of having at least 01 success: 0.4269
# Sample size: 115  --> Probability of having at least 01 success: 0.433
# Sample size: 116  --> Probability of having at least 01 success: 0.4357
# Sample size: 117  --> Probability of having at least 01 success: 0.4403
# Sample size: 118  --> Probability of having at least 01 success: 0.4424
# Sample size: 119  --> Probability of having at least 01 success: 0.4465
# Sample size: 120  --> Probability of having at least 01 success: 0.4519
# Sample size: 121  --> Probability of having at least 01 success: 0.4517
# Sample size: 122  --> Probability of having at least 01 success: 0.4536
# Sample size: 123  --> Probability of having at least 01 success: 0.4517
# Sample size: 124  --> Probability of having at least 01 success: 0.46
# Sample size: 125  --> Probability of having at least 01 success: 0.46
# Sample size: 126  --> Probability of having at least 01 success: 0.4624
# Sample size: 127  --> Probability of having at least 01 success: 0.4661
# Sample size: 128  --> Probability of having at least 01 success: 0.4657
# Sample size: 129  --> Probability of having at least 01 success: 0.4725
# Sample size: 130  --> Probability of having at least 01 success: 0.4763
# Sample size: 131  --> Probability of having at least 01 success: 0.4766
# Sample size: 132  --> Probability of having at least 01 success: 0.4744
# Sample size: 133  --> Probability of having at least 01 success: 0.4751
# Sample size: 134  --> Probability of having at least 01 success: 0.4865
# Sample size: 135  --> Probability of having at least 01 success: 0.4928
# Sample size: 136  --> Probability of having at least 01 success: 0.5011
# Sample size: 137  --> Probability of having at least 01 success: 0.4992
# Sample size: 138  --> Probability of having at least 01 success: 0.5027
# Sample size: 139  --> Probability of having at least 01 success: 0.4949
# Sample size: 140  --> Probability of having at least 01 success: 0.4984
# Sample size: 141  --> Probability of having at least 01 success: 0.5019
# Sample size: 142  --> Probability of having at least 01 success: 0.5029
# Sample size: 143  --> Probability of having at least 01 success: 0.5123
# Sample size: 144  --> Probability of having at least 01 success: 0.5081
# Sample size: 145  --> Probability of having at least 01 success: 0.5113
# Sample size: 146  --> Probability of having at least 01 success: 0.5161
# Sample size: 147  --> Probability of having at least 01 success: 0.5127
# Sample size: 148  --> Probability of having at least 01 success: 0.523
# Sample size: 149  --> Probability of having at least 01 success: 0.5378
# Sample size: 150  --> Probability of having at least 01 success: 0.5274
# Sample size: 151  --> Probability of having at least 01 success: 0.5344
# Sample size: 152  --> Probability of having at least 01 success: 0.5334
# Sample size: 153  --> Probability of having at least 01 success: 0.529
# Sample size: 154  --> Probability of having at least 01 success: 0.5374
# Sample size: 155  --> Probability of having at least 01 success: 0.5445
# Sample size: 156  --> Probability of having at least 01 success: 0.5393
# Sample size: 157  --> Probability of having at least 01 success: 0.5389
# Sample size: 158  --> Probability of having at least 01 success: 0.5534
# Sample size: 159  --> Probability of having at least 01 success: 0.5499
# Sample size: 160  --> Probability of having at least 01 success: 0.5455
# Sample size: 161  --> Probability of having at least 01 success: 0.5619
# Sample size: 162  --> Probability of having at least 01 success: 0.5543
# Sample size: 163  --> Probability of having at least 01 success: 0.556
# Sample size: 164  --> Probability of having at least 01 success: 0.567
# Sample size: 165  --> Probability of having at least 01 success: 0.5584
# Sample size: 166  --> Probability of having at least 01 success: 0.5621
# Sample size: 167  --> Probability of having at least 01 success: 0.5681
# Sample size: 168  --> Probability of having at least 01 success: 0.5701
# Sample size: 169  --> Probability of having at least 01 success: 0.5664
# Sample size: 170  --> Probability of having at least 01 success: 0.5659
# Sample size: 171  --> Probability of having at least 01 success: 0.5677
# Sample size: 172  --> Probability of having at least 01 success: 0.5712
# Sample size: 173  --> Probability of having at least 01 success: 0.5754
# Sample size: 174  --> Probability of having at least 01 success: 0.5841
# Sample size: 175  --> Probability of having at least 01 success: 0.5753
# Sample size: 176  --> Probability of having at least 01 success: 0.5836
# Sample size: 177  --> Probability of having at least 01 success: 0.5898
# Sample size: 178  --> Probability of having at least 01 success: 0.5839
# Sample size: 179  --> Probability of having at least 01 success: 0.5855
# Sample size: 180  --> Probability of having at least 01 success: 0.5852
# Sample size: 181  --> Probability of having at least 01 success: 0.5909
# Sample size: 182  --> Probability of having at least 01 success: 0.5935
# Sample size: 183  --> Probability of having at least 01 success: 0.5998
# Sample size: 184  --> Probability of having at least 01 success: 0.6036
# Sample size: 185  --> Probability of having at least 01 success: 0.6052
# Sample size: 186  --> Probability of having at least 01 success: 0.6025
# Sample size: 187  --> Probability of having at least 01 success: 0.6019
# Sample size: 188  --> Probability of having at least 01 success: 0.6133
# Sample size: 189  --> Probability of having at least 01 success: 0.6113
# Sample size: 190  --> Probability of having at least 01 success: 0.6079
# Sample size: 191  --> Probability of having at least 01 success: 0.6158
# Sample size: 192  --> Probability of having at least 01 success: 0.6242
# Sample size: 193  --> Probability of having at least 01 success: 0.6147
# Sample size: 194  --> Probability of having at least 01 success: 0.6245
# Sample size: 195  --> Probability of having at least 01 success: 0.6264
# Sample size: 196  --> Probability of having at least 01 success: 0.6115
# Sample size: 197  --> Probability of having at least 01 success: 0.6305
# Sample size: 198  --> Probability of having at least 01 success: 0.6338
# Sample size: 199  --> Probability of having at least 01 success: 0.6302
# Sample size: 200  --> Probability of having at least 01 success: 0.6238
# Sample size: 201  --> Probability of having at least 01 success: 0.6275
# Sample size: 202  --> Probability of having at least 01 success: 0.6299
# Sample size: 203  --> Probability of having at least 01 success: 0.6287
# Sample size: 204  --> Probability of having at least 01 success: 0.6373
# Sample size: 205  --> Probability of having at least 01 success: 0.6384
# Sample size: 206  --> Probability of having at least 01 success: 0.6323
# Sample size: 207  --> Probability of having at least 01 success: 0.6494
# Sample size: 208  --> Probability of having at least 01 success: 0.639
# Sample size: 209  --> Probability of having at least 01 success: 0.6482
# Sample size: 210  --> Probability of having at least 01 success: 0.6547
# Sample size: 211  --> Probability of having at least 01 success: 0.6573
# Sample size: 212  --> Probability of having at least 01 success: 0.6551
# Sample size: 213  --> Probability of having at least 01 success: 0.6562
# Sample size: 214  --> Probability of having at least 01 success: 0.65
# Sample size: 215  --> Probability of having at least 01 success: 0.6503
# Sample size: 216  --> Probability of having at least 01 success: 0.6524
# Sample size: 217  --> Probability of having at least 01 success: 0.6562
# Sample size: 218  --> Probability of having at least 01 success: 0.6622
# Sample size: 219  --> Probability of having at least 01 success: 0.664
# Sample size: 220  --> Probability of having at least 01 success: 0.6714
# Sample size: 221  --> Probability of having at least 01 success: 0.6636
# Sample size: 222  --> Probability of having at least 01 success: 0.6764
# Sample size: 223  --> Probability of having at least 01 success: 0.6734
# Sample size: 224  --> Probability of having at least 01 success: 0.6682
# Sample size: 225  --> Probability of having at least 01 success: 0.6741
# Sample size: 226  --> Probability of having at least 01 success: 0.6764
# Sample size: 227  --> Probability of having at least 01 success: 0.6755
# Sample size: 228  --> Probability of having at least 01 success: 0.6777
# Sample size: 229  --> Probability of having at least 01 success: 0.6837
# Sample size: 230  --> Probability of having at least 01 success: 0.6827
# Sample size: 231  --> Probability of having at least 01 success: 0.6824
# Sample size: 232  --> Probability of having at least 01 success: 0.6905
# Sample size: 233  --> Probability of having at least 01 success: 0.6887
# Sample size: 234  --> Probability of having at least 01 success: 0.6902
# Sample size: 235  --> Probability of having at least 01 success: 0.6849
# Sample size: 236  --> Probability of having at least 01 success: 0.6895
# Sample size: 237  --> Probability of having at least 01 success: 0.6902
# Sample size: 238  --> Probability of having at least 01 success: 0.698
# Sample size: 239  --> Probability of having at least 01 success: 0.6914
# Sample size: 240  --> Probability of having at least 01 success: 0.7
# Sample size: 241  --> Probability of having at least 01 success: 0.6959
# Sample size: 242  --> Probability of having at least 01 success: 0.7044
# Sample size: 243  --> Probability of having at least 01 success: 0.7025
# Sample size: 244  --> Probability of having at least 01 success: 0.6973
# Sample size: 245  --> Probability of having at least 01 success: 0.708
# Sample size: 246  --> Probability of having at least 01 success: 0.7042
# Sample size: 247  --> Probability of having at least 01 success: 0.706
# Sample size: 248  --> Probability of having at least 01 success: 0.7046
# Sample size: 249  --> Probability of having at least 01 success: 0.7133
# Sample size: 250  --> Probability of having at least 01 success: 0.7054
# Sample size: 251  --> Probability of having at least 01 success: 0.7102
# Sample size: 252  --> Probability of having at least 01 success: 0.7128
# Sample size: 253  --> Probability of having at least 01 success: 0.7195
# Sample size: 254  --> Probability of having at least 01 success: 0.7157
# Sample size: 255  --> Probability of having at least 01 success: 0.719
# Sample size: 256  --> Probability of having at least 01 success: 0.7177
# Sample size: 257  --> Probability of having at least 01 success: 0.721
# Sample size: 258  --> Probability of having at least 01 success: 0.7177
# Sample size: 259  --> Probability of having at least 01 success: 0.7244
# Sample size: 260  --> Probability of having at least 01 success: 0.7209
# Sample size: 261  --> Probability of having at least 01 success: 0.728
# Sample size: 262  --> Probability of having at least 01 success: 0.7254
# Sample size: 263  --> Probability of having at least 01 success: 0.7294
# Sample size: 264  --> Probability of having at least 01 success: 0.727
# Sample size: 265  --> Probability of having at least 01 success: 0.7255
# Sample size: 266  --> Probability of having at least 01 success: 0.7278
# Sample size: 267  --> Probability of having at least 01 success: 0.7353
# Sample size: 268  --> Probability of having at least 01 success: 0.7375
# Sample size: 269  --> Probability of having at least 01 success: 0.7391
# Sample size: 270  --> Probability of having at least 01 success: 0.7378
# Sample size: 271  --> Probability of having at least 01 success: 0.7397
# Sample size: 272  --> Probability of having at least 01 success: 0.7468
# Sample size: 273  --> Probability of having at least 01 success: 0.7473
# Sample size: 274  --> Probability of having at least 01 success: 0.7472
# Sample size: 275  --> Probability of having at least 01 success: 0.751
# Sample size: 276  --> Probability of having at least 01 success: 0.7352
# Sample size: 277  --> Probability of having at least 01 success: 0.7449
# Sample size: 278  --> Probability of having at least 01 success: 0.7498
# Sample size: 279  --> Probability of having at least 01 success: 0.7505
# Sample size: 280  --> Probability of having at least 01 success: 0.7532
# Sample size: 281  --> Probability of having at least 01 success: 0.7538
# Sample size: 282  --> Probability of having at least 01 success: 0.7556
# Sample size: 283  --> Probability of having at least 01 success: 0.7624
# Sample size: 284  --> Probability of having at least 01 success: 0.7517
# Sample size: 285  --> Probability of having at least 01 success: 0.753
# Sample size: 286  --> Probability of having at least 01 success: 0.761
# Sample size: 287  --> Probability of having at least 01 success: 0.7605
# Sample size: 288  --> Probability of having at least 01 success: 0.7565
# Sample size: 289  --> Probability of having at least 01 success: 0.7626
# Sample size: 290  --> Probability of having at least 01 success: 0.7581
# Sample size: 291  --> Probability of having at least 01 success: 0.7679
# Sample size: 292  --> Probability of having at least 01 success: 0.7717
# Sample size: 293  --> Probability of having at least 01 success: 0.7666
# Sample size: 294  --> Probability of having at least 01 success: 0.7633
# Sample size: 295  --> Probability of having at least 01 success: 0.764
# Sample size: 296  --> Probability of having at least 01 success: 0.7683
# Sample size: 297  --> Probability of having at least 01 success: 0.7728
# Sample size: 298  --> Probability of having at least 01 success: 0.7802
# Sample size: 299  --> Probability of having at least 01 success: 0.7834
# Sample size: 300  --> Probability of having at least 01 success: 0.7817
# Sample size: 301  --> Probability of having at least 01 success: 0.7709
# Sample size: 302  --> Probability of having at least 01 success: 0.7748
# Sample size: 303  --> Probability of having at least 01 success: 0.7751
# Sample size: 304  --> Probability of having at least 01 success: 0.7767
# Sample size: 305  --> Probability of having at least 01 success: 0.7801
# Sample size: 306  --> Probability of having at least 01 success: 0.7739
# Sample size: 307  --> Probability of having at least 01 success: 0.7805
# Sample size: 308  --> Probability of having at least 01 success: 0.7832
# Sample size: 309  --> Probability of having at least 01 success: 0.7883
# Sample size: 310  --> Probability of having at least 01 success: 0.7839
# Sample size: 311  --> Probability of having at least 01 success: 0.7883
# Sample size: 312  --> Probability of having at least 01 success: 0.7884
# Sample size: 313  --> Probability of having at least 01 success: 0.7874
# Sample size: 314  --> Probability of having at least 01 success: 0.7893
# Sample size: 315  --> Probability of having at least 01 success: 0.7943
# Sample size: 316  --> Probability of having at least 01 success: 0.7939
# Sample size: 317  --> Probability of having at least 01 success: 0.7953
# Sample size: 318  --> Probability of having at least 01 success: 0.7917
# Sample size: 319  --> Probability of having at least 01 success: 0.7944
# Sample size: 320  --> Probability of having at least 01 success: 0.8014
# Sample size: 321  --> Probability of having at least 01 success: 0.7981
# Sample size: 322  --> Probability of having at least 01 success: 0.8026
# Sample size: 323  --> Probability of having at least 01 success: 0.7946
# Sample size: 324  --> Probability of having at least 01 success: 0.8063
# Sample size: 325  --> Probability of having at least 01 success: 0.8028
# Sample size: 326  --> Probability of having at least 01 success: 0.8052
# Sample size: 327  --> Probability of having at least 01 success: 0.8088
# Sample size: 328  --> Probability of having at least 01 success: 0.8103
# Sample size: 329  --> Probability of having at least 01 success: 0.8074
# Sample size: 330  --> Probability of having at least 01 success: 0.8016
# Sample size: 331  --> Probability of having at least 01 success: 0.8047
# Sample size: 332  --> Probability of having at least 01 success: 0.8032
# Sample size: 333  --> Probability of having at least 01 success: 0.8044
# Sample size: 334  --> Probability of having at least 01 success: 0.804
# Sample size: 335  --> Probability of having at least 01 success: 0.8148
# Sample size: 336  --> Probability of having at least 01 success: 0.8111
# Sample size: 337  --> Probability of having at least 01 success: 0.8189
# Sample size: 338  --> Probability of having at least 01 success: 0.8163
# Sample size: 339  --> Probability of having at least 01 success: 0.8225
# Sample size: 340  --> Probability of having at least 01 success: 0.8221
# Sample size: 341  --> Probability of having at least 01 success: 0.8172
# Sample size: 342  --> Probability of having at least 01 success: 0.8225
# Sample size: 343  --> Probability of having at least 01 success: 0.8164
# Sample size: 344  --> Probability of having at least 01 success: 0.8175
# Sample size: 345  --> Probability of having at least 01 success: 0.8237
# Sample size: 346  --> Probability of having at least 01 success: 0.8224
# Sample size: 347  --> Probability of having at least 01 success: 0.8228
# Sample size: 348  --> Probability of having at least 01 success: 0.8272
# Sample size: 349  --> Probability of having at least 01 success: 0.8198
# Sample size: 350  --> Probability of having at least 01 success: 0.8174
# Sample size: 351  --> Probability of having at least 01 success: 0.8265
# Sample size: 352  --> Probability of having at least 01 success: 0.832
# Sample size: 353  --> Probability of having at least 01 success: 0.8288
# Sample size: 354  --> Probability of having at least 01 success: 0.8257
# Sample size: 355  --> Probability of having at least 01 success: 0.8301
# Sample size: 356  --> Probability of having at least 01 success: 0.8301
# Sample size: 357  --> Probability of having at least 01 success: 0.8266
# Sample size: 358  --> Probability of having at least 01 success: 0.8362
# Sample size: 359  --> Probability of having at least 01 success: 0.827
# Sample size: 360  --> Probability of having at least 01 success: 0.8291
# Sample size: 361  --> Probability of having at least 01 success: 0.8397
# Sample size: 362  --> Probability of having at least 01 success: 0.8359
# Sample size: 363  --> Probability of having at least 01 success: 0.8358
# Sample size: 364  --> Probability of having at least 01 success: 0.834
# Sample size: 365  --> Probability of having at least 01 success: 0.835
# Sample size: 366  --> Probability of having at least 01 success: 0.8364
# Sample size: 367  --> Probability of having at least 01 success: 0.841
# Sample size: 368  --> Probability of having at least 01 success: 0.8396
# Sample size: 369  --> Probability of having at least 01 success: 0.8397
# Sample size: 370  --> Probability of having at least 01 success: 0.8391
# Sample size: 371  --> Probability of having at least 01 success: 0.839
# Sample size: 372  --> Probability of having at least 01 success: 0.8425
# Sample size: 373  --> Probability of having at least 01 success: 0.8478
# Sample size: 374  --> Probability of having at least 01 success: 0.8409
# Sample size: 375  --> Probability of having at least 01 success: 0.8427
# Sample size: 376  --> Probability of having at least 01 success: 0.8441
# Sample size: 377  --> Probability of having at least 01 success: 0.8428
# Sample size: 378  --> Probability of having at least 01 success: 0.8452
# Sample size: 379  --> Probability of having at least 01 success: 0.8457
# Sample size: 380  --> Probability of having at least 01 success: 0.8434
# Sample size: 381  --> Probability of having at least 01 success: 0.847
# Sample size: 382  --> Probability of having at least 01 success: 0.8513
# Sample size: 383  --> Probability of having at least 01 success: 0.8485
# Sample size: 384  --> Probability of having at least 01 success: 0.8523
# Sample size: 385  --> Probability of having at least 01 success: 0.8611
# Sample size: 386  --> Probability of having at least 01 success: 0.8569
# Sample size: 387  --> Probability of having at least 01 success: 0.8522
# Sample size: 388  --> Probability of having at least 01 success: 0.8533
# Sample size: 389  --> Probability of having at least 01 success: 0.8507
# Sample size: 390  --> Probability of having at least 01 success: 0.8589
# Sample size: 391  --> Probability of having at least 01 success: 0.8607
# Sample size: 392  --> Probability of having at least 01 success: 0.8586
# Sample size: 393  --> Probability of having at least 01 success: 0.8553
# Sample size: 394  --> Probability of having at least 01 success: 0.8657
# Sample size: 395  --> Probability of having at least 01 success: 0.857
# Sample size: 396  --> Probability of having at least 01 success: 0.8595
# Sample size: 397  --> Probability of having at least 01 success: 0.8663
# Sample size: 398  --> Probability of having at least 01 success: 0.8591
# Sample size: 399  --> Probability of having at least 01 success: 0.8605
# Sample size: 400  --> Probability of having at least 01 success: 0.8605
# Sample size: 401  --> Probability of having at least 01 success: 0.8708
# Sample size: 402  --> Probability of having at least 01 success: 0.863
# Sample size: 403  --> Probability of having at least 01 success: 0.8652
# Sample size: 404  --> Probability of having at least 01 success: 0.8638
# Sample size: 405  --> Probability of having at least 01 success: 0.8629
# Sample size: 406  --> Probability of having at least 01 success: 0.8681
# Sample size: 407  --> Probability of having at least 01 success: 0.8593
# Sample size: 408  --> Probability of having at least 01 success: 0.8675
# Sample size: 409  --> Probability of having at least 01 success: 0.8716
# Sample size: 410  --> Probability of having at least 01 success: 0.8655
# Sample size: 411  --> Probability of having at least 01 success: 0.864
# Sample size: 412  --> Probability of having at least 01 success: 0.862
# Sample size: 413  --> Probability of having at least 01 success: 0.8686
# Sample size: 414  --> Probability of having at least 01 success: 0.8754
# Sample size: 415  --> Probability of having at least 01 success: 0.8735
# Sample size: 416  --> Probability of having at least 01 success: 0.8711
# Sample size: 417  --> Probability of having at least 01 success: 0.8771
# Sample size: 418  --> Probability of having at least 01 success: 0.8655
# Sample size: 419  --> Probability of having at least 01 success: 0.8793
# Sample size: 420  --> Probability of having at least 01 success: 0.8733
# Sample size: 421  --> Probability of having at least 01 success: 0.8785
# Sample size: 422  --> Probability of having at least 01 success: 0.8807
# Sample size: 423  --> Probability of having at least 01 success: 0.8869
# Sample size: 424  --> Probability of having at least 01 success: 0.8742
# Sample size: 425  --> Probability of having at least 01 success: 0.8747
# Sample size: 426  --> Probability of having at least 01 success: 0.8851
# Sample size: 427  --> Probability of having at least 01 success: 0.8823
# Sample size: 428  --> Probability of having at least 01 success: 0.8806
# Sample size: 429  --> Probability of having at least 01 success: 0.883
# Sample size: 430  --> Probability of having at least 01 success: 0.8789
# Sample size: 431  --> Probability of having at least 01 success: 0.8819
# Sample size: 432  --> Probability of having at least 01 success: 0.8842
# Sample size: 433  --> Probability of having at least 01 success: 0.886
# Sample size: 434  --> Probability of having at least 01 success: 0.8832
# Sample size: 435  --> Probability of having at least 01 success: 0.8906
# Sample size: 436  --> Probability of having at least 01 success: 0.8848
# Sample size: 437  --> Probability of having at least 01 success: 0.8887
# Sample size: 438  --> Probability of having at least 01 success: 0.89
# Sample size: 439  --> Probability of having at least 01 success: 0.8876
# Sample size: 440  --> Probability of having at least 01 success: 0.8849
# Sample size: 441  --> Probability of having at least 01 success: 0.8862
# Sample size: 442  --> Probability of having at least 01 success: 0.8892
# Sample size: 443  --> Probability of having at least 01 success: 0.8876
# Sample size: 444  --> Probability of having at least 01 success: 0.8899
# Sample size: 445  --> Probability of having at least 01 success: 0.8892
# Sample size: 446  --> Probability of having at least 01 success: 0.8894
# Sample size: 447  --> Probability of having at least 01 success: 0.8989
# Sample size: 448  --> Probability of having at least 01 success: 0.8935
# Sample size: 449  --> Probability of having at least 01 success: 0.8896
# Sample size: 450  --> Probability of having at least 01 success: 0.8938
# Sample size: 451  --> Probability of having at least 01 success: 0.896
# Sample size: 452  --> Probability of having at least 01 success: 0.8958
# Sample size: 453  --> Probability of having at least 01 success: 0.8997
# Sample size: 454  --> Probability of having at least 01 success: 0.893
# Sample size: 455  --> Probability of having at least 01 success: 0.8968
# Sample size: 456  --> Probability of having at least 01 success: 0.8881
# Sample size: 457  --> Probability of having at least 01 success: 0.8927
# Sample size: 458  --> Probability of having at least 01 success: 0.8965
# Sample size: 459  --> Probability of having at least 01 success: 0.8974
# Sample size: 460  --> Probability of having at least 01 success: 0.8938
# Sample size: 461  --> Probability of having at least 01 success: 0.8938
# Sample size: 462  --> Probability of having at least 01 success: 0.9017
# Sample size: 463  --> Probability of having at least 01 success: 0.9
# Sample size: 464  --> Probability of having at least 01 success: 0.8986
# Sample size: 465  --> Probability of having at least 01 success: 0.9037
# Sample size: 466  --> Probability of having at least 01 success: 0.9069
# Sample size: 467  --> Probability of having at least 01 success: 0.907
# Sample size: 468  --> Probability of having at least 01 success: 0.9061
# Sample size: 469  --> Probability of having at least 01 success: 0.904
# Sample size: 470  --> Probability of having at least 01 success: 0.9032
# Sample size: 471  --> Probability of having at least 01 success: 0.9064
# Sample size: 472  --> Probability of having at least 01 success: 0.9051
# Sample size: 473  --> Probability of having at least 01 success: 0.904
# Sample size: 474  --> Probability of having at least 01 success: 0.903
# Sample size: 475  --> Probability of having at least 01 success: 0.9038
# Sample size: 476  --> Probability of having at least 01 success: 0.9064
# Sample size: 477  --> Probability of having at least 01 success: 0.903
# Sample size: 478  --> Probability of having at least 01 success: 0.9087
# Sample size: 479  --> Probability of having at least 01 success: 0.9055
# Sample size: 480  --> Probability of having at least 01 success: 0.912
# Sample size: 481  --> Probability of having at least 01 success: 0.9099
# Sample size: 482  --> Probability of having at least 01 success: 0.9129
# Sample size: 483  --> Probability of having at least 01 success: 0.91
# Sample size: 484  --> Probability of having at least 01 success: 0.9114
# Sample size: 485  --> Probability of having at least 01 success: 0.9105
# Sample size: 486  --> Probability of having at least 01 success: 0.9053
# Sample size: 487  --> Probability of having at least 01 success: 0.9072
# Sample size: 488  --> Probability of having at least 01 success: 0.9082
# Sample size: 489  --> Probability of having at least 01 success: 0.9139
# Sample size: 490  --> Probability of having at least 01 success: 0.9063
# Sample size: 491  --> Probability of having at least 01 success: 0.9129
# Sample size: 492  --> Probability of having at least 01 success: 0.9161
# Sample size: 493  --> Probability of having at least 01 success: 0.9137
# Sample size: 494  --> Probability of having at least 01 success: 0.9127
# Sample size: 495  --> Probability of having at least 01 success: 0.9123
# Sample size: 496  --> Probability of having at least 01 success: 0.9169
# Sample size: 497  --> Probability of having at least 01 success: 0.9119
# Sample size: 498  --> Probability of having at least 01 success: 0.913
# Sample size: 499  --> Probability of having at least 01 success: 0.9122
# Sample size: 500  --> Probability of having at least 01 success: 0.9155
# Sample size: 501  --> Probability of having at least 01 success: 0.9147
# Sample size: 502  --> Probability of having at least 01 success: 0.9204
# Sample size: 503  --> Probability of having at least 01 success: 0.9215
# Sample size: 504  --> Probability of having at least 01 success: 0.9171
# Sample size: 505  --> Probability of having at least 01 success: 0.9188
# Sample size: 506  --> Probability of having at least 01 success: 0.918
# Sample size: 507  --> Probability of having at least 01 success: 0.9197
# Sample size: 508  --> Probability of having at least 01 success: 0.9198
# Sample size: 509  --> Probability of having at least 01 success: 0.9265
# Sample size: 510  --> Probability of having at least 01 success: 0.9183
# Sample size: 511  --> Probability of having at least 01 success: 0.9225
# Sample size: 512  --> Probability of having at least 01 success: 0.9196
# Sample size: 513  --> Probability of having at least 01 success: 0.9216
# Sample size: 514  --> Probability of having at least 01 success: 0.923
# Sample size: 515  --> Probability of having at least 01 success: 0.9215
# Sample size: 516  --> Probability of having at least 01 success: 0.923
# Sample size: 517  --> Probability of having at least 01 success: 0.9233
# Sample size: 518  --> Probability of having at least 01 success: 0.9223
# Sample size: 519  --> Probability of having at least 01 success: 0.9263
# Sample size: 520  --> Probability of having at least 01 success: 0.9283
# Sample size: 521  --> Probability of having at least 01 success: 0.9216
# Sample size: 522  --> Probability of having at least 01 success: 0.9233
# Sample size: 523  --> Probability of having at least 01 success: 0.9261
# Sample size: 524  --> Probability of having at least 01 success: 0.9233
# Sample size: 525  --> Probability of having at least 01 success: 0.9288
# Sample size: 526  --> Probability of having at least 01 success: 0.9268
# Sample size: 527  --> Probability of having at least 01 success: 0.9282
# Sample size: 528  --> Probability of having at least 01 success: 0.9256
# Sample size: 529  --> Probability of having at least 01 success: 0.9263
# Sample size: 530  --> Probability of having at least 01 success: 0.9274
# Sample size: 531  --> Probability of having at least 01 success: 0.9241
# Sample size: 532  --> Probability of having at least 01 success: 0.9249
# Sample size: 533  --> Probability of having at least 01 success: 0.932
# Sample size: 534  --> Probability of having at least 01 success: 0.9327
# Sample size: 535  --> Probability of having at least 01 success: 0.9339
# Sample size: 536  --> Probability of having at least 01 success: 0.9304
# Sample size: 537  --> Probability of having at least 01 success: 0.9272
# Sample size: 538  --> Probability of having at least 01 success: 0.9315
# Sample size: 539  --> Probability of having at least 01 success: 0.9308
# Sample size: 540  --> Probability of having at least 01 success: 0.9318
# Sample size: 541  --> Probability of having at least 01 success: 0.9337
# Sample size: 542  --> Probability of having at least 01 success: 0.9304
# Sample size: 543  --> Probability of having at least 01 success: 0.9347
# Sample size: 544  --> Probability of having at least 01 success: 0.9354
# Sample size: 545  --> Probability of having at least 01 success: 0.9311
# Sample size: 546  --> Probability of having at least 01 success: 0.9335
# Sample size: 547  --> Probability of having at least 01 success: 0.9345
# Sample size: 548  --> Probability of having at least 01 success: 0.9329
# Sample size: 549  --> Probability of having at least 01 success: 0.933
# Sample size: 550  --> Probability of having at least 01 success: 0.9362
# Sample size: 551  --> Probability of having at least 01 success: 0.9313
# Sample size: 552  --> Probability of having at least 01 success: 0.935
# Sample size: 553  --> Probability of having at least 01 success: 0.9374
# Sample size: 554  --> Probability of having at least 01 success: 0.9373
# Sample size: 555  --> Probability of having at least 01 success: 0.9323
# Sample size: 556  --> Probability of having at least 01 success: 0.9359
# Sample size: 557  --> Probability of having at least 01 success: 0.937
# Sample size: 558  --> Probability of having at least 01 success: 0.9359
# Sample size: 559  --> Probability of having at least 01 success: 0.9375
# Sample size: 560  --> Probability of having at least 01 success: 0.9357
# Sample size: 561  --> Probability of having at least 01 success: 0.9358
# Sample size: 562  --> Probability of having at least 01 success: 0.9375
# Sample size: 563  --> Probability of having at least 01 success: 0.9398
# Sample size: 564  --> Probability of having at least 01 success: 0.9423
# Sample size: 565  --> Probability of having at least 01 success: 0.9388
# Sample size: 566  --> Probability of having at least 01 success: 0.942
# Sample size: 567  --> Probability of having at least 01 success: 0.9413
# Sample size: 568  --> Probability of having at least 01 success: 0.9434
# Sample size: 569  --> Probability of having at least 01 success: 0.9411
# Sample size: 570  --> Probability of having at least 01 success: 0.9432
# Sample size: 571  --> Probability of having at least 01 success: 0.9396
# Sample size: 572  --> Probability of having at least 01 success: 0.9376
# Sample size: 573  --> Probability of having at least 01 success: 0.942
# Sample size: 574  --> Probability of having at least 01 success: 0.9427
# Sample size: 575  --> Probability of having at least 01 success: 0.9409
# Sample size: 576  --> Probability of having at least 01 success: 0.942
# Sample size: 577  --> Probability of having at least 01 success: 0.9456
# Sample size: 578  --> Probability of having at least 01 success: 0.9412
# Sample size: 579  --> Probability of having at least 01 success: 0.9466
# Sample size: 580  --> Probability of having at least 01 success: 0.9417
# Sample size: 581  --> Probability of having at least 01 success: 0.9449
# Sample size: 582  --> Probability of having at least 01 success: 0.946
# Sample size: 583  --> Probability of having at least 01 success: 0.944
# Sample size: 584  --> Probability of having at least 01 success: 0.9445
# Sample size: 585  --> Probability of having at least 01 success: 0.9471
# Sample size: 586  --> Probability of having at least 01 success: 0.9439
# Sample size: 587  --> Probability of having at least 01 success: 0.9455
# Sample size: 588  --> Probability of having at least 01 success: 0.9462
# Sample size: 589  --> Probability of having at least 01 success: 0.9458
# Sample size: 590  --> Probability of having at least 01 success: 0.9437
# Sample size: 591  --> Probability of having at least 01 success: 0.9446
# Sample size: 592  --> Probability of having at least 01 success: 0.9464
# Sample size: 593  --> Probability of having at least 01 success: 0.9475
# Sample size: 594  --> Probability of having at least 01 success: 0.951
# Sample size: 595  --> Probability of having at least 01 success: 0.9492
# Sample size: 596  --> Probability of having at least 01 success: 0.9467
# Sample size: 597  --> Probability of having at least 01 success: 0.9508
# Sample size: 598  --> Probability of having at least 01 success: 0.9488
# Sample size: 599  --> Probability of having at least 01 success: 0.9509
# Sample size: 600  --> Probability of having at least 01 success: 0.9513
# Sample size: 601  --> Probability of having at least 01 success: 0.9527
# Sample size: 602  --> Probability of having at least 01 success: 0.9474
# Sample size: 603  --> Probability of having at least 01 success: 0.9494
# Sample size: 604  --> Probability of having at least 01 success: 0.9474
# Sample size: 605  --> Probability of having at least 01 success: 0.954
# Sample size: 606  --> Probability of having at least 01 success: 0.9486
# Sample size: 607  --> Probability of having at least 01 success: 0.9502
# Sample size: 608  --> Probability of having at least 01 success: 0.9514
# Sample size: 609  --> Probability of having at least 01 success: 0.953
# Sample size: 610  --> Probability of having at least 01 success: 0.9508
# Sample size: 611  --> Probability of having at least 01 success: 0.9538
# Sample size: 612  --> Probability of having at least 01 success: 0.9564
# Sample size: 613  --> Probability of having at least 01 success: 0.9561
# Sample size: 614  --> Probability of having at least 01 success: 0.9549
# Sample size: 615  --> Probability of having at least 01 success: 0.9552
# Sample size: 616  --> Probability of having at least 01 success: 0.9525
# Sample size: 617  --> Probability of having at least 01 success: 0.9539
# Sample size: 618  --> Probability of having at least 01 success: 0.9507
# Sample size: 619  --> Probability of having at least 01 success: 0.9546
# Sample size: 620  --> Probability of having at least 01 success: 0.9516
# Sample size: 621  --> Probability of having at least 01 success: 0.9514
# Sample size: 622  --> Probability of having at least 01 success: 0.9549
# Sample size: 623  --> Probability of having at least 01 success: 0.9569
# Sample size: 624  --> Probability of having at least 01 success: 0.9592
# Sample size: 625  --> Probability of having at least 01 success: 0.951
# Sample size: 626  --> Probability of having at least 01 success: 0.9533
# Sample size: 627  --> Probability of having at least 01 success: 0.9563
# Sample size: 628  --> Probability of having at least 01 success: 0.9554
# Sample size: 629  --> Probability of having at least 01 success: 0.9554
# Sample size: 630  --> Probability of having at least 01 success: 0.9573
# Sample size: 631  --> Probability of having at least 01 success: 0.9572
# Sample size: 632  --> Probability of having at least 01 success: 0.9588
# Sample size: 633  --> Probability of having at least 01 success: 0.9593
# Sample size: 634  --> Probability of having at least 01 success: 0.9573
# Sample size: 635  --> Probability of having at least 01 success: 0.9572
# Sample size: 636  --> Probability of having at least 01 success: 0.9586
# Sample size: 637  --> Probability of having at least 01 success: 0.9558
# Sample size: 638  --> Probability of having at least 01 success: 0.9581
# Sample size: 639  --> Probability of having at least 01 success: 0.9595
# Sample size: 640  --> Probability of having at least 01 success: 0.9587
# Sample size: 641  --> Probability of having at least 01 success: 0.9597
# Sample size: 642  --> Probability of having at least 01 success: 0.9593
# Sample size: 643  --> Probability of having at least 01 success: 0.959
# Sample size: 644  --> Probability of having at least 01 success: 0.9603
# Sample size: 645  --> Probability of having at least 01 success: 0.9618
# Sample size: 646  --> Probability of having at least 01 success: 0.9628
# Sample size: 647  --> Probability of having at least 01 success: 0.961
# Sample size: 648  --> Probability of having at least 01 success: 0.9615
# Sample size: 649  --> Probability of having at least 01 success: 0.9586
# Sample size: 650  --> Probability of having at least 01 success: 0.9598
# Sample size: 651  --> Probability of having at least 01 success: 0.958
# Sample size: 652  --> Probability of having at least 01 success: 0.9619
# Sample size: 653  --> Probability of having at least 01 success: 0.9619
# Sample size: 654  --> Probability of having at least 01 success: 0.9621
# Sample size: 655  --> Probability of having at least 01 success: 0.9606
# Sample size: 656  --> Probability of having at least 01 success: 0.962
# Sample size: 657  --> Probability of having at least 01 success: 0.963
# Sample size: 658  --> Probability of having at least 01 success: 0.9622
# Sample size: 659  --> Probability of having at least 01 success: 0.9631
# Sample size: 660  --> Probability of having at least 01 success: 0.9619
# Sample size: 661  --> Probability of having at least 01 success: 0.961
# Sample size: 662  --> Probability of having at least 01 success: 0.9617
# Sample size: 663  --> Probability of having at least 01 success: 0.9621
# Sample size: 664  --> Probability of having at least 01 success: 0.9621
# Sample size: 665  --> Probability of having at least 01 success: 0.9611
# Sample size: 666  --> Probability of having at least 01 success: 0.966
# Sample size: 667  --> Probability of having at least 01 success: 0.9632
# Sample size: 668  --> Probability of having at least 01 success: 0.9595
# Sample size: 669  --> Probability of having at least 01 success: 0.9656
# Sample size: 670  --> Probability of having at least 01 success: 0.9639
# Sample size: 671  --> Probability of having at least 01 success: 0.963
# Sample size: 672  --> Probability of having at least 01 success: 0.9627
# Sample size: 673  --> Probability of having at least 01 success: 0.9647
# Sample size: 674  --> Probability of having at least 01 success: 0.9651
# Sample size: 675  --> Probability of having at least 01 success: 0.9661
# Sample size: 676  --> Probability of having at least 01 success: 0.9611
# Sample size: 677  --> Probability of having at least 01 success: 0.965
# Sample size: 678  --> Probability of having at least 01 success: 0.9642
# Sample size: 679  --> Probability of having at least 01 success: 0.9649
# Sample size: 680  --> Probability of having at least 01 success: 0.9625
# Sample size: 681  --> Probability of having at least 01 success: 0.965
# Sample size: 682  --> Probability of having at least 01 success: 0.9689
# Sample size: 683  --> Probability of having at least 01 success: 0.9659
# Sample size: 684  --> Probability of having at least 01 success: 0.9688
# Sample size: 685  --> Probability of having at least 01 success: 0.9675
# Sample size: 686  --> Probability of having at least 01 success: 0.9644
# Sample size: 687  --> Probability of having at least 01 success: 0.9692
# Sample size: 688  --> Probability of having at least 01 success: 0.966
# Sample size: 689  --> Probability of having at least 01 success: 0.9669
# Sample size: 690  --> Probability of having at least 01 success: 0.9699
# Sample size: 691  --> Probability of having at least 01 success: 0.968
# Sample size: 692  --> Probability of having at least 01 success: 0.9637
# Sample size: 693  --> Probability of having at least 01 success: 0.9711
# Sample size: 694  --> Probability of having at least 01 success: 0.9663
# Sample size: 695  --> Probability of having at least 01 success: 0.9657
# Sample size: 696  --> Probability of having at least 01 success: 0.9649
# Sample size: 697  --> Probability of having at least 01 success: 0.97
# Sample size: 698  --> Probability of having at least 01 success: 0.9684
# Sample size: 699  --> Probability of having at least 01 success: 0.9683
# Sample size: 700  --> Probability of having at least 01 success: 0.9681
# Sample size: 701  --> Probability of having at least 01 success: 0.9698
# Sample size: 702  --> Probability of having at least 01 success: 0.9723
# Sample size: 703  --> Probability of having at least 01 success: 0.9689
# Sample size: 704  --> Probability of having at least 01 success: 0.9666
# Sample size: 705  --> Probability of having at least 01 success: 0.9688
# Sample size: 706  --> Probability of having at least 01 success: 0.973
# Sample size: 707  --> Probability of having at least 01 success: 0.972
# Sample size: 708  --> Probability of having at least 01 success: 0.9697
# Sample size: 709  --> Probability of having at least 01 success: 0.9707
# Sample size: 710  --> Probability of having at least 01 success: 0.9695
# Sample size: 711  --> Probability of having at least 01 success: 0.9705
# Sample size: 712  --> Probability of having at least 01 success: 0.9689
# Sample size: 713  --> Probability of having at least 01 success: 0.9731
# Sample size: 714  --> Probability of having at least 01 success: 0.9736
# Sample size: 715  --> Probability of having at least 01 success: 0.9717
# Sample size: 716  --> Probability of having at least 01 success: 0.9699
# Sample size: 717  --> Probability of having at least 01 success: 0.9735
# Sample size: 718  --> Probability of having at least 01 success: 0.9698
# Sample size: 719  --> Probability of having at least 01 success: 0.9716
# Sample size: 720  --> Probability of having at least 01 success: 0.9728
# Sample size: 721  --> Probability of having at least 01 success: 0.9711
# Sample size: 722  --> Probability of having at least 01 success: 0.9726
# Sample size: 723  --> Probability of having at least 01 success: 0.9741
# Sample size: 724  --> Probability of having at least 01 success: 0.9724
# Sample size: 725  --> Probability of having at least 01 success: 0.972
# Sample size: 726  --> Probability of having at least 01 success: 0.9717
# Sample size: 727  --> Probability of having at least 01 success: 0.9717
# Sample size: 728  --> Probability of having at least 01 success: 0.9742
# Sample size: 729  --> Probability of having at least 01 success: 0.9722
# Sample size: 730  --> Probability of having at least 01 success: 0.9728
# Sample size: 731  --> Probability of having at least 01 success: 0.9735
# Sample size: 732  --> Probability of having at least 01 success: 0.9747
# Sample size: 733  --> Probability of having at least 01 success: 0.9759
# Sample size: 734  --> Probability of having at least 01 success: 0.9756
# Sample size: 735  --> Probability of having at least 01 success: 0.9725
# Sample size: 736  --> Probability of having at least 01 success: 0.9724
# Sample size: 737  --> Probability of having at least 01 success: 0.974
# Sample size: 738  --> Probability of having at least 01 success: 0.9735
# Sample size: 739  --> Probability of having at least 01 success: 0.9754
# Sample size: 740  --> Probability of having at least 01 success: 0.9747
# Sample size: 741  --> Probability of having at least 01 success: 0.9743
# Sample size: 742  --> Probability of having at least 01 success: 0.975
# Sample size: 743  --> Probability of having at least 01 success: 0.9731
# Sample size: 744  --> Probability of having at least 01 success: 0.9739
# Sample size: 745  --> Probability of having at least 01 success: 0.9777
# Sample size: 746  --> Probability of having at least 01 success: 0.9758
# Sample size: 747  --> Probability of having at least 01 success: 0.9761
# Sample size: 748  --> Probability of having at least 01 success: 0.9723
# Sample size: 749  --> Probability of having at least 01 success: 0.9764
# Sample size: 750  --> Probability of having at least 01 success: 0.9773
# Sample size: 751  --> Probability of having at least 01 success: 0.9763
# Sample size: 752  --> Probability of having at least 01 success: 0.9746
# Sample size: 753  --> Probability of having at least 01 success: 0.9754
# Sample size: 754  --> Probability of having at least 01 success: 0.9758
# Sample size: 755  --> Probability of having at least 01 success: 0.9763
# Sample size: 756  --> Probability of having at least 01 success: 0.976
# Sample size: 757  --> Probability of having at least 01 success: 0.9763
# Sample size: 758  --> Probability of having at least 01 success: 0.9768
# Sample size: 759  --> Probability of having at least 01 success: 0.9765
# Sample size: 760  --> Probability of having at least 01 success: 0.9771
# Sample size: 761  --> Probability of having at least 01 success: 0.9787
# Sample size: 762  --> Probability of having at least 01 success: 0.9776
# Sample size: 763  --> Probability of having at least 01 success: 0.9766
# Sample size: 764  --> Probability of having at least 01 success: 0.9765
# Sample size: 765  --> Probability of having at least 01 success: 0.9786
# Sample size: 766  --> Probability of having at least 01 success: 0.9766
# ...
# Sample size: 779  --> Probability of having at least 01 success: 0.9779
# Sample size: 780  --> Probability of having at least 01 success: 0.979
# Sample size: 781  --> Probability of having at least 01 success: 0.9817
# Sample size: 782  --> Probability of having at least 01 success: 0.9791
# Sample size: 783  --> Probability of having at least 01 success: 0.9818
# Sample size: 784  --> Probability of having at least 01 success: 0.9801
# Sample size: 785  --> Probability of having at least 01 success: 0.9785
# Sample size: 786  --> Probability of having at least 01 success: 0.9791
# Sample size: 787  --> Probability of having at least 01 success: 0.9816
# Sample size: 788  --> Probability of having at least 01 success: 0.9811
# Sample size: 789  --> Probability of having at least 01 success: 0.9807
# Sample size: 790  --> Probability of having at least 01 success: 0.98
# Sample size: 791  --> Probability of having at least 01 success: 0.9798
# Sample size: 792  --> Probability of having at least 01 success: 0.98
# Sample size: 793  --> Probability of having at least 01 success: 0.9784
# Sample size: 794  --> Probability of having at least 01 success: 0.9799
# Sample size: 795  --> Probability of having at least 01 success: 0.9788
# Sample size: 796  --> Probability of having at least 01 success: 0.9792
# Sample size: 797  --> Probability of having at least 01 success: 0.9818
# Sample size: 798  --> Probability of having at least 01 success: 0.9825
# Sample size: 799  --> Probability of having at least 01 success: 0.9783
# Sample size: 800  --> Probability of having at least 01 success: 0.9831
# Sample size: 801  --> Probability of having at least 01 success: 0.9808
# Sample size: 802  --> Probability of having at least 01 success: 0.9828
# Sample size: 803  --> Probability of having at least 01 success: 0.9832
# Sample size: 804  --> Probability of having at least 01 success: 0.9797
# Sample size: 805  --> Probability of having at least 01 success: 0.9787
# Sample size: 806  --> Probability of having at least 01 success: 0.9811
# Sample size: 807  --> Probability of having at least 01 success: 0.982
# Sample size: 808  --> Probability of having at least 01 success: 0.9835
# Sample size: 809  --> Probability of having at least 01 success: 0.9837
# Sample size: 810  --> Probability of having at least 01 success: 0.9821
# Sample size: 811  --> Probability of having at least 01 success: 0.9809
# Sample size: 812  --> Probability of having at least 01 success: 0.9813
# Sample size: 813  --> Probability of having at least 01 success: 0.983
# Sample size: 814  --> Probability of having at least 01 success: 0.9827
# Sample size: 815  --> Probability of having at least 01 success: 0.9821
# Sample size: 816  --> Probability of having at least 01 success: 0.9798
# Sample size: 817  --> Probability of having at least 01 success: 0.9832
# Sample size: 818  --> Probability of having at least 01 success: 0.9839
# Sample size: 819  --> Probability of having at least 01 success: 0.9809
# Sample size: 820  --> Probability of having at least 01 success: 0.9823
# Sample size: 821  --> Probability of having at least 01 success: 0.9836
# Sample size: 822  --> Probability of having at least 01 success: 0.9816
# Sample size: 823  --> Probability of having at least 01 success: 0.982
# Sample size: 824  --> Probability of having at least 01 success: 0.9846
# Sample size: 825  --> Probability of having at least 01 success: 0.9818
# Sample size: 826  --> Probability of having at least 01 success: 0.9821
# Sample size: 827  --> Probability of having at least 01 success: 0.9851
# Sample size: 828  --> Probability of having at least 01 success: 0.9848
# Sample size: 829  --> Probability of having at least 01 success: 0.9838
# Sample size: 830  --> Probability of having at least 01 success: 0.9818
# Sample size: 831  --> Probability of having at least 01 success: 0.9826
# Sample size: 832  --> Probability of having at least 01 success: 0.9832
# Sample size: 833  --> Probability of having at least 01 success: 0.9835
# Sample size: 834  --> Probability of having at least 01 success: 0.9846
# Sample size: 835  --> Probability of having at least 01 success: 0.983
# Sample size: 836  --> Probability of having at least 01 success: 0.9838
# Sample size: 837  --> Probability of having at least 01 success: 0.9841
# Sample size: 838  --> Probability of having at least 01 success: 0.9853
# Sample size: 839  --> Probability of having at least 01 success: 0.9833
# Sample size: 840  --> Probability of having at least 01 success: 0.9829
# Sample size: 841  --> Probability of having at least 01 success: 0.985
# Sample size: 842  --> Probability of having at least 01 success: 0.9859
# Sample size: 843  --> Probability of having at least 01 success: 0.9838
# Sample size: 844  --> Probability of having at least 01 success: 0.9868
# Sample size: 845  --> Probability of having at least 01 success: 0.9841
# Sample size: 846  --> Probability of having at least 01 success: 0.9853
# Sample size: 847  --> Probability of having at least 01 success: 0.9844
# Sample size: 848  --> Probability of having at least 01 success: 0.9863
# Sample size: 849  --> Probability of having at least 01 success: 0.9854
# Sample size: 850  --> Probability of having at least 01 success: 0.9833
# Sample size: 851  --> Probability of having at least 01 success: 0.9851
# Sample size: 852  --> Probability of having at least 01 success: 0.986
# Sample size: 853  --> Probability of having at least 01 success: 0.9863
# Sample size: 854  --> Probability of having at least 01 success: 0.9856
# Sample size: 855  --> Probability of having at least 01 success: 0.9854
# Sample size: 856  --> Probability of having at least 01 success: 0.986
# Sample size: 857  --> Probability of having at least 01 success: 0.987
# Sample size: 858  --> Probability of having at least 01 success: 0.9863
# Sample size: 859  --> Probability of having at least 01 success: 0.9881
# Sample size: 860  --> Probability of having at least 01 success: 0.9861
# Sample size: 861  --> Probability of having at least 01 success: 0.9847
# Sample size: 862  --> Probability of having at least 01 success: 0.9838
# Sample size: 863  --> Probability of having at least 01 success: 0.9851
# Sample size: 864  --> Probability of having at least 01 success: 0.9839
# Sample size: 865  --> Probability of having at least 01 success: 0.9856
# Sample size: 866  --> Probability of having at least 01 success: 0.9868
# Sample size: 867  --> Probability of having at least 01 success: 0.9875
# Sample size: 868  --> Probability of having at least 01 success: 0.9866
# Sample size: 869  --> Probability of having at least 01 success: 0.985
# Sample size: 870  --> Probability of having at least 01 success: 0.9888
# Sample size: 871  --> Probability of having at least 01 success: 0.9859
# Sample size: 872  --> Probability of having at least 01 success: 0.9878
# Sample size: 873  --> Probability of having at least 01 success: 0.9866
# Sample size: 874  --> Probability of having at least 01 success: 0.9854
# Sample size: 875  --> Probability of having at least 01 success: 0.9883
# Sample size: 876  --> Probability of having at least 01 success: 0.9872
# Sample size: 877  --> Probability of having at least 01 success: 0.9852
# Sample size: 878  --> Probability of having at least 01 success: 0.9874
# Sample size: 879  --> Probability of having at least 01 success: 0.9862
# Sample size: 880  --> Probability of having at least 01 success: 0.9865
# Sample size: 881  --> Probability of having at least 01 success: 0.987
# Sample size: 882  --> Probability of having at least 01 success: 0.9858
# Sample size: 883  --> Probability of having at least 01 success: 0.9885
# Sample size: 884  --> Probability of having at least 01 success: 0.9888
# Sample size: 885  --> Probability of having at least 01 success: 0.988
# Sample size: 886  --> Probability of having at least 01 success: 0.9869
# Sample size: 887  --> Probability of having at least 01 success: 0.9879
# Sample size: 888  --> Probability of having at least 01 success: 0.9898
# Sample size: 889  --> Probability of having at least 01 success: 0.9876
# Sample size: 890  --> Probability of having at least 01 success: 0.9885
# Sample size: 891  --> Probability of having at least 01 success: 0.9889
# Sample size: 892  --> Probability of having at least 01 success: 0.9858
# Sample size: 893  --> Probability of having at least 01 success: 0.9874
# Sample size: 894  --> Probability of having at least 01 success: 0.9871
# Sample size: 895  --> Probability of having at least 01 success: 0.9885
# Sample size: 896  --> Probability of having at least 01 success: 0.9882
# Sample size: 897  --> Probability of having at least 01 success: 0.9868
# Sample size: 898  --> Probability of having at least 01 success: 0.9883
# Sample size: 899  --> Probability of having at least 01 success: 0.9876
# Sample size: 900  --> Probability of having at least 01 success: 0.9865
# Sample size: 901  --> Probability of having at least 01 success: 0.988
# Sample size: 902  --> Probability of having at least 01 success: 0.9884
# Sample size: 903  --> Probability of having at least 01 success: 0.9879
# Sample size: 904  --> Probability of having at least 01 success: 0.988
# Sample size: 905  --> Probability of having at least 01 success: 0.9887
# Sample size: 906  --> Probability of having at least 01 success: 0.9868
# Sample size: 907  --> Probability of having at least 01 success: 0.9898
# Sample size: 908  --> Probability of having at least 01 success: 0.9894
# Sample size: 909  --> Probability of having at least 01 success: 0.9885
# Sample size: 910  --> Probability of having at least 01 success: 0.9912
# Sample size: 911  --> Probability of having at least 01 success: 0.9883
# Sample size: 912  --> Probability of having at least 01 success: 0.9904
# Sample size: 913  --> Probability of having at least 01 success: 0.9878
# Sample size: 914  --> Probability of having at least 01 success: 0.991
# Sample size: 915  --> Probability of having at least 01 success: 0.9894
# Sample size: 916  --> Probability of having at least 01 success: 0.9888
# Sample size: 917  --> Probability of having at least 01 success: 0.9896
# Sample size: 918  --> Probability of having at least 01 success: 0.9895
# Sample size: 919  --> Probability of having at least 01 success: 0.9891
# Sample size: 920  --> Probability of having at least 01 success: 0.9904
# Sample size: 921  --> Probability of having at least 01 success: 0.9897
# Sample size: 922  --> Probability of having at least 01 success: 0.9913
# Sample size: 923  --> Probability of having at least 01 success: 0.9895
# Sample size: 924  --> Probability of having at least 01 success: 0.9892
# Sample size: 925  --> Probability of having at least 01 success: 0.9897
# Sample size: 926  --> Probability of having at least 01 success: 0.9905
# Sample size: 927  --> Probability of having at least 01 success: 0.9899
# Sample size: 928  --> Probability of having at least 01 success: 0.9913
# Sample size: 929  --> Probability of having at least 01 success: 0.9908
# Sample size: 930  --> Probability of having at least 01 success: 0.9881
# Sample size: 931  --> Probability of having at least 01 success: 0.9895
# Sample size: 932  --> Probability of having at least 01 success: 0.9903
# Sample size: 933  --> Probability of having at least 01 success: 0.9917
# Sample size: 934  --> Probability of having at least 01 success: 0.99
# Sample size: 935  --> Probability of having at least 01 success: 0.9894
# Sample size: 936  --> Probability of having at least 01 success: 0.9898
# Sample size: 937  --> Probability of having at least 01 success: 0.9901
# Sample size: 938  --> Probability of having at least 01 success: 0.9889
# Sample size: 939  --> Probability of having at least 01 success: 0.9905
# Sample size: 940  --> Probability of having at least 01 success: 0.9913
# Sample size: 941  --> Probability of having at least 01 success: 0.9912
# Sample size: 942  --> Probability of having at least 01 success: 0.9918
# Sample size: 943  --> Probability of having at least 01 success: 0.9906
# Sample size: 944  --> Probability of having at least 01 success: 0.989
# Sample size: 945  --> Probability of having at least 01 success: 0.99
# Sample size: 946  --> Probability of having at least 01 success: 0.9901
# Sample size: 947  --> Probability of having at least 01 success: 0.9906
# Sample size: 948  --> Probability of having at least 01 success: 0.9908
# Sample size: 949  --> Probability of having at least 01 success: 0.9923
# Sample size: 950  --> Probability of having at least 01 success: 0.9902
# Sample size: 951  --> Probability of having at least 01 success: 0.9896
# Sample size: 952  --> Probability of having at least 01 success: 0.9919
# Sample size: 953  --> Probability of having at least 01 success: 0.9911
# Sample size: 954  --> Probability of having at least 01 success: 0.9918
# Sample size: 955  --> Probability of having at least 01 success: 0.9911
# Sample size: 956  --> Probability of having at least 01 success: 0.9916
# Sample size: 957  --> Probability of having at least 01 success: 0.9921
# Sample size: 958  --> Probability of having at least 01 success: 0.9935
# Sample size: 959  --> Probability of having at least 01 success: 0.9916
# Sample size: 960  --> Probability of having at least 01 success: 0.9911
# Sample size: 961  --> Probability of having at least 01 success: 0.9922
# Sample size: 962  --> Probability of having at least 01 success: 0.9923
# Sample size: 963  --> Probability of having at least 01 success: 0.9909
# Sample size: 964  --> Probability of having at least 01 success: 0.9911
# Sample size: 965  --> Probability of having at least 01 success: 0.9913
# Sample size: 966  --> Probability of having at least 01 success: 0.9907
# Sample size: 967  --> Probability of having at least 01 success: 0.9922
# Sample size: 968  --> Probability of having at least 01 success: 0.9912
# Sample size: 969  --> Probability of having at least 01 success: 0.991
# Sample size: 970  --> Probability of having at least 01 success: 0.9931
# Sample size: 971  --> Probability of having at least 01 success: 0.9934
# Sample size: 972  --> Probability of having at least 01 success: 0.9927
# Sample size: 973  --> Probability of having at least 01 success: 0.9913
# Sample size: 974  --> Probability of having at least 01 success: 0.9913
# Sample size: 975  --> Probability of having at least 01 success: 0.9931
# Sample size: 976  --> Probability of having at least 01 success: 0.9933
# Sample size: 977  --> Probability of having at least 01 success: 0.9924
# Sample size: 978  --> Probability of having at least 01 success: 0.9924
# Sample size: 979  --> Probability of having at least 01 success: 0.993
# Sample size: 980  --> Probability of having at least 01 success: 0.9916
# Sample size: 981  --> Probability of having at least 01 success: 0.9906
# Sample size: 982  --> Probability of having at least 01 success: 0.992
# Sample size: 983  --> Probability of having at least 01 success: 0.9922
# Sample size: 984  --> Probability of having at least 01 success: 0.9942
# Sample size: 985  --> Probability of having at least 01 success: 0.9928
# Sample size: 986  --> Probability of having at least 01 success: 0.9923
# Sample size: 987  --> Probability of having at least 01 success: 0.9932
# Sample size: 988  --> Probability of having at least 01 success: 0.9915
# Sample size: 989  --> Probability of having at least 01 success: 0.9922
# Sample size: 990  --> Probability of having at least 01 success: 0.9915
# Sample size: 991  --> Probability of having at least 01 success: 0.9942
# Sample size: 992  --> Probability of having at least 01 success: 0.9922
# Sample size: 993  --> Probability of having at least 01 success: 0.9936
# Sample size: 994  --> Probability of having at least 01 success: 0.9935
# Sample size: 995  --> Probability of having at least 01 success: 0.9931
# Sample size: 996  --> Probability of having at least 01 success: 0.9934
# Sample size: 997  --> Probability of having at least 01 success: 0.9931
# Sample size: 998  --> Probability of having at least 01 success: 0.9925
# Sample size: 999  --> Probability of having at least 01 success: 0.9942
# Sample size: 1000  --> Probability of having at least 01 success: 0.992
